# %% [markdown]
# <a href="https://colab.research.google.com/github/nanda3-vit/HeartDiseasePractice/blob/main/southafricaheartdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/sample_data/1.SouthAfricaHDataset.csv')

# %%
print('Data First 5 Rows Show\n')
data.head()
# Out:
# Data First 5 Rows Show
#    sbp  tobacco   ldl  adiposity  famhist  type a  Obesity  Alcohol  age  chd
# 0  160    12.00  5.73      23.11        1      49    25.30    97.20   52    1
# 1  144     0.01  4.41      28.61        0      55    28.87     2.06   63    1
# 2  118     0.08  3.48      32.28        1      52    29.14     3.81   46    0
# 3  170     7.50  6.41      38.03        1      51    31.99    24.26   58    1
# 4  134    13.60  3.50      27.78        1      60    25.99    57.34   49    1

# %%
print('Data Last 5 Rows Show\n')
data.tail()
# Out:
# Data Last 5 Rows Show
#      sbp  tobacco    ldl  adiposity  ...  Obesity  Alcohol  age  chd
# 457  214      0.4   5.98      31.72  ...    28.45     0.00   58    0
# 458  182      4.2   4.41      32.10  ...    28.61    18.72   52    1
# 459  108      3.0   1.59      15.23  ...    20.09    26.64   55    0
# 460  118      5.4  11.61      30.79  ...    27.35    23.97   40    0
# 461  132      0.0   4.82      33.41  ...    14.70     0.00   46    1
#
# [5 rows x 10 columns]

# %%
print('Data Show Describe\n')
data.describe()
# Out:
# Data Show Describe
#               sbp     tobacco         ldl  ...     Alcohol         age         chd
# count  462.000000  462.000000  462.000000  ...  462.000000  462.000000  462.000000
# mean   138.326840    3.635649    4.740325  ...   17.044394   42.816017    0.346320
# std     20.496317    4.593024    2.070909  ...   24.481059   14.608956    0.476313
# min    101.000000    0.000000    0.980000  ...    0.000000   15.000000    0.000000
# 25%    124.000000    0.052500    3.282500  ...    0.510000   31.000000    0.000000
# 50%    134.000000    2.000000    4.340000  ...    7.510000   45.000000    0.000000
# 75%    148.000000    5.500000    5.790000  ...   23.892500   55.000000    1.000000
# max    218.000000   31.200000   15.330000  ...  147.190000   64.000000    1.000000
#
# [8 rows x 10 columns]

# %%
print('Data Show Info\n')
data.info()
# Out:
# Data Show Info
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sbp        462 non-null    int64
#  1   tobacco    462 non-null    float64
#  2   ldl        462 non-null    float64
#  3   adiposity  462 non-null    float64
#  4   famhist    462 non-null    int64
#  5   type a     462 non-null    int64
#  6   Obesity    462 non-null    float64
#  7   Alcohol    462 non-null    float64
#  8   age        462 non-null    int64
#  9   chd        462 non-null    int64
# dtypes: float64(5), int64(5)
# memory usage: 36.2 KB

# %%
print('Data Show Columns:\n')
data.columns
# Out:
# Data Show Columns:
# Index(['sbp', 'tobacco', 'ldl', 'adiposity', 'famhist', 'type a', 'Obesity',
#        'Alcohol', 'age', 'chd'],
#       dtype='object')

# %%
data.sample(frac=0.01)
# Out:
#      sbp  tobacco   ldl  adiposity  famhist  type a  Obesity  Alcohol  age  chd
# 113  174     0.00  8.46      35.10        1      35    25.27     0.00   61    1
# 100  136     8.00  7.85      23.81        1      51    22.69     2.78   50    0
# 333  152    19.45  4.22      29.81        0      28    23.95     0.00   59    1
# 198  160     3.00  9.19      26.47        1      39    28.25    14.40   54    1
# 33   126     8.75  6.53      34.02        0      49    30.25     0.00   41    1

# %%
data.sample(5)
# Out:
#      sbp  tobacco   ldl  adiposity  famhist  type a  Obesity  Alcohol  age  chd
# 270  130     0.00  4.16      39.43        1      46    30.01     0.00   55    1
# 91   120     3.70  4.02      39.66        0      61    30.57     0.00   64    1
# 1    144     0.01  4.41      28.61        0      55    28.87     2.06   63    1
# 66   124     4.82  3.24      21.10        1      48    28.49     8.42   30    0
# 31   158     1.02  6.33      23.88        0      66    22.13    24.99   46    1

# %%
data.columns
# Out:
# Index(['sbp', 'tobacco', 'ldl', 'adiposity', 'famhist', 'type a', 'Obesity',
#        'Alcohol', 'age', 'chd'],
#       dtype='object')

# %%
print('Data Shape Show\n')
data.shape
# Out:
# Data Shape Show
# (462, 10)

# %%
print('Data Sum of Null Values \n')
data.isnull().sum()
# Out:
# Data Sum of Null Values
# sbp          0
# tobacco      0
# ldl          0
# adiposity    0
# famhist      0
# type a       0
# Obesity      0
# Alcohol      0
# age          0
# chd          0
# dtype: int64

# %%
data.isnull().values.any()
# Out:
# False

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True,fmt='.1f')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5},annot=True)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
data.age.value_counts()[:10]
# Out:
# 16    20
# 58    17
# 17    17
# 61    16
# 59    16
# 55    16
# 60    15
# 49    14
# 53    14
# 45    14
# Name: age, dtype: int64

# %%
sns.barplot(x=data.age.value_counts()[:10].index,y=data.age.value_counts()[:10].values)
plt.xlabel('Age')
plt.ylabel('Age Counter')
plt.title('Age Analysis System')
plt.show()

# %%
minAge=min(data.age)
maxAge=max(data.age)
meanAge=data.age.mean()
print('Min Age :',minAge)
print('Max Age :',maxAge)
print('Mean Age :',meanAge)
# Out:
# Min Age : 15
# Max Age : 64
# Mean Age : 42.816017316017316

# %%
young_ages=data[(data.age>=29)&(data.age<40)]
middle_ages=data[(data.age>=40)&(data.age<55)]
elderly_ages=data[(data.age>55)]
print('Young Ages :',len(young_ages))
print('Middle Ages :',len(middle_ages))
print('Elderly Ages :',len(elderly_ages))
# Out:
# Young Ages : 82
# Middle Ages : 156
# Elderly Ages : 114

# %%
sns.barplot(x=['young ages','middle ages','elderly ages'],y=[len(young_ages),len(middle_ages),len(elderly_ages)])
plt.xlabel('Age Range')
plt.ylabel('Age Counts')
plt.title('Ages State in Dataset')
plt.show()

# %%
data['AgeRange']=0
youngAge_index=data[(data.age>=29)&(data.age<40)].index
middleAge_index=data[(data.age>=40)&(data.age<55)].index
elderlyAge_index=data[(data.age>55)].index

# %%
for index in elderlyAge_index:
    data.loc[index,'AgeRange']=2
    
for index in middleAge_index:
    data.loc[index,'AgeRange']=1

for index in youngAge_index:
    data.loc[index,'AgeRange']=0

# %%
sns.swarmplot(x="AgeRange", y="age",hue='famhist',
              palette=["r", "c", "y"], data=data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 11.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 19.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 25.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_color_codes("deep")
sns.barplot(y="AgeRange", x="famhist", data=data,
            label="Total", color="b")
plt.show()

# %%
sns.countplot(elderly_ages.famhist)
plt.title("Elderly Family Operations")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.violinplot(data.age, palette="Set3", bw=.2, cut=1, linewidth=1)
plt.xticks(rotation=90)
plt.title("Age Rates")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,7))
sns.violinplot(x=data.age,y=data.chd)
plt.xticks(rotation=90)
plt.legend()
plt.title("Age & CHD System")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
colors = ['green','red','yellow']
explode = [0,0,0.1]
plt.figure(figsize = (5,5))
#plt.pie([target_0_agerang_0,target_1_agerang_0], explode=explode, labels=['Target 0 Age Range 0','Target 1 Age Range 0'], colors=colors, autopct='%1.1f%%')
plt.pie([len(young_ages),len(middle_ages),len(elderly_ages)],labels=['young ages','middle ages','elderly ages'],explode=explode,colors=colors, autopct='%1.1f%%')
plt.title('Age States',color = 'blue',fontsize = 15)
plt.show()

# %%
data.famhist.value_counts()
# Out:
# 0    270
# 1    192
# Name: famhist, dtype: int64

# %%
sns.countplot(data.famhist)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot(x="type a", y="age",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=data)

# %%
data.head()
# Out:
#    sbp  tobacco   ldl  adiposity  famhist  ...  Obesity  Alcohol  age  chd  AgeRange
# 0  160    12.00  5.73      23.11        1  ...    25.30    97.20   52    1         1
# 1  144     0.01  4.41      28.61        0  ...    28.87     2.06   63    1         2
# 2  118     0.08  3.48      32.28        1  ...    29.14     3.81   46    0         1
# 3  170     7.50  6.41      38.03        1  ...    31.99    24.26   58    1         2
# 4  134    13.60  3.50      27.78        1  ...    25.99    57.34   49    1         1
#
# [5 rows x 11 columns]

# %%
data.Obesity.value_counts()
# Out:
# 24.86    4
# 26.09    4
# 22.01    3
# 27.29    3
# 21.94    3
#         ..
# 27.78    1
# 33.10    1
# 21.03    1
# 27.66    1
# 30.25    1
# Name: Obesity, Length: 400, dtype: int64

# %%
sns.lmplot(x="famhist", y="ldl",data=data,hue="age")
plt.show()

# %%
target_0_agerang_0=len(data[(data.chd==0)&(data.AgeRange==0)])
target_1_agerang_0=len(data[(data.chd==1)&(data.AgeRange==0)])

# %%
colors = ['red','yellow']
explode = [0,0.1]
plt.figure(figsize = (5,5))
plt.pie([target_0_agerang_0,target_1_agerang_0], explode=explode, labels=['CHD 0 Age Range 0','CHD 1 Age Range 0'], colors=colors, autopct='%1.1f%%')
plt.title('CHD vs Age Range Young Age ',color = 'blue',fontsize = 15)
plt.show()

# %%
target_0_agerang_1=len(data[(data.chd==0)&(data.AgeRange==1)])
target_1_agerang_1=len(data[(data.chd==1)&(data.AgeRange==1)])

# %%
colors = ['yellow','red']
explode = [0.1,0]
plt.figure(figsize = (5,5))
plt.pie([target_0_agerang_1,target_1_agerang_1], explode=explode, labels=['CHD 0 Age Range 1','CHD 1 Age Range 1'], colors=colors, autopct='%1.1f%%')
plt.title('CHD vs Age Range Middle Age',color = 'blue',fontsize = 15)
plt.show()

# %%
target_0_agerang_2=len(data[(data.chd==0)&(data.AgeRange==2)])
target_1_agerang_2=len(data[(data.chd==1)&(data.AgeRange==2)])

# %%
colors = ['cyan','red']
explode = [0,0.1]
plt.figure(figsize = (5,5))
plt.pie([target_0_agerang_2,target_1_agerang_2], explode=explode, labels=['CHD 0 Age Range 2','CHD 1 Age Range 2'], colors=colors, autopct='%1.1f%%')
plt.title('CHD vs Age Range Elderly Age ',color = 'blue',fontsize = 15)
plt.show()

# %%
data.tobacco.value_counts()[:20]
# Out:
# 0.00     107
# 6.00      11
# 3.00      10
# 0.40       8
# 4.00       8
# 4.20       7
# 4.50       7
# 1.20       5
# 0.60       5
# 2.00       5
# 1.50       5
# 12.00      5
# 8.80       4
# 0.12       4
# 5.60       4
# 7.50       4
# 5.50       4
# 0.05       4
# 2.60       3
# 1.80       3
# 0.80       3
# 2.80       3
# 0.50       3
# 0.28       3
# 10.50      3
# 1.70       3
# 0.90       3
# 6.60       3
# 3.60       3
# 8.00       3
# 2.40       3
# 1.40       2
# 0.10       2
# 6.40       2
# 0.08       2
# 5.40       2
# 7.28       2
# 0.70       2
# 4.18       2
# 1.15       2
# 11.20      2
# 4.46       2
# 0.52       2
# 1.68       2
# 0.04       2
# 0.54       2
# 5.04       2
# 14.00      2
# 9.00       2
# 7.00       2
# 8.20       2
# 3.20       2
# 4.05       2
# 15.00      2
# 3.50       2
# 1.60       2
# 20.00      2
# Name: tobacco, dtype: int64

# %%
sns.barplot(x=data.tobacco.value_counts()[:20].index,y=data.tobacco.value_counts()[:20].values)
plt.xlabel('Tobacco')
plt.ylabel('Count')
plt.title('Tobacco Counts')
plt.xticks(rotation=45)
plt.show()

# %%
sns.swarmplot(x=data.age)
plt.title('Age Rates')
plt.show()

# %%
age_unique=sorted(data.age.unique())
age_tobacco_values=data.groupby('age')['tobacco'].count().values
mean_tobacco=[]
for i,age in enumerate(age_unique):
    mean_tobacco.append(sum(data[data['age']==age].tobacco)/age_tobacco_values[i])

# %%
#data_sorted=data.sort_values(by='age',ascending=True)
plt.figure(figsize=(10,5))
sns.pointplot(x=age_unique,y=mean_tobacco,color='red',alpha=0.8)
plt.xlabel('age',fontsize = 15,color='blue')
plt.xticks(rotation=45)
plt.ylabel('tobacco',fontsize = 15,color='blue')
plt.title('Age vs Tobacco',fontsize = 15,color='blue')
plt.grid()
plt.show()

# %%
age_range_tobacco=data.groupby('AgeRange')['tobacco'].mean()

# %%
sns.barplot(x=age_range_tobacco.index,y=age_range_tobacco.values)
plt.xlabel('Age Range Values')
plt.ylabel('Maximum Tobacco By Age Range')
plt.title('illustration of the tobacco to the age range')
plt.show()
#As shown in this graph, this rate decreases as the heart rate 
#is faster and in old age areas.

# %%
Obesity_tobacco=data.groupby('Obesity')['tobacco'].mean()

# %%
sns.barplot(x=Obesity_tobacco.index,y=Obesity_tobacco.values)
plt.xlabel('Obesity')
plt.ylabel('Maximum tobacco By obesity Values')
plt.title('Illustration of tobacco to degree of obesity type')
plt.show()
#As seen in this graph, it is seen that the heart rate is less 
#when the chest pain is low. But in cases where chest pain is 
#1, it is observed that the area is more. 2 and 3 were found to 
#be of the same degree.

# %%
data.adiposity.value_counts()
# Out:
# 30.79    3
# 29.30    3
# 21.10    3
# 27.55    3
# 30.84    2
#         ..
# 27.87    1
# 23.81    1
# 31.35    1
# 39.68    1
# 22.00    1
# Name: adiposity, Length: 408, dtype: int64

# %%
sns.countplot(data.adiposity)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data[(data.adiposity==0)]
#as seen, only 50% was understood to be 50% target.
# Out:
# Empty DataFrame
# Columns: [sbp, tobacco, ldl, adiposity, famhist, type a, Obesity, Alcohol, age, chd, AgeRange]
# Index: []

# %%
sns.countplot(data.chd)
plt.xlabel('CHD')
plt.ylabel('Count')
plt.title('CHD Counter 1 & 0')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(data.chd,hue=data.famhist)
plt.xlabel('CHD')
plt.ylabel('Count')
plt.title('CHD & famhist Counter 1 & 0')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#determine the age ranges of patients with and without sickness and make analyzes about them
age_counter_chd_1=[]
age_counter_chd_0=[]
for age in data.age.unique():
    age_counter_chd_1.append(len(data[(data['age']==age)&(data.chd==1)]))
    age_counter_chd_0.append(len(data[(data['age']==age)&(data.chd==0)]))

#now, draw show on graph

# %%
#Target 1 & 0 show graph on scatter
plt.scatter(x=data.age.unique(),y=age_counter_chd_1,color='blue',label='CHD 1')
plt.scatter(x=data.age.unique(),y=age_counter_chd_0,color='red',label='CHD 0')
plt.legend(loc='upper right',frameon=True)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('CHD 0 & CHD 1 State')
plt.show()

# %%
sns.lineplot(x="famhist", y="ldl",
             hue="chd",data=data)
plt.show()

# %%
data.head()
# Out:
#    sbp  tobacco   ldl  adiposity  famhist  ...  Obesity  Alcohol  age  chd  AgeRange
# 0  160    12.00  5.73      23.11        1  ...    25.30    97.20   52    1         1
# 1  144     0.01  4.41      28.61        0  ...    28.87     2.06   63    1         2
# 2  118     0.08  3.48      32.28        1  ...    29.14     3.81   46    0         1
# 3  170     7.50  6.41      38.03        1  ...    31.99    24.26   58    1         2
# 4  134    13.60  3.50      27.78        1  ...    25.99    57.34   49    1         1
#
# [5 rows x 11 columns]

# %%
g = sns.catplot(x="AgeRange", y="sbp",
                 hue="famhist",
                 data=data, kind="bar")
plt.show()

# %%
ax = sns.barplot("famhist", "sbp", data=data,
                  linewidth=2.5, facecolor=(1, 1, 1, 0),
                  errcolor=".2", edgecolor=".2")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
male_young_t_1=data[(data['famhist']==1)&(data['AgeRange']==0)&(data['chd']==1)]
male_middle_t_1=data[(data['famhist']==1)&(data['AgeRange']==1)&(data['chd']==1)]
male_elderly_t_1=data[(data['famhist']==1)&(data['AgeRange']==2)&(data['chd']==1)]
print(len(male_young_t_1))
print(len(male_middle_t_1))
print(len(male_elderly_t_1))
# Out:
# 19
# 39
# 38

# %%
f,ax1=plt.subplots(figsize=(20,10))
sns.pointplot(x=np.arange(len(male_young_t_1)),y=male_young_t_1.sbp,color='lime',alpha=0.8,label='Young')
sns.pointplot(x=np.arange(len(male_middle_t_1)),y=male_middle_t_1.sbp,color='black',alpha=0.8,label='Middle')
sns.pointplot(x=np.arange(len(male_elderly_t_1)),y=male_elderly_t_1.sbp,color='red',alpha=0.8,label='Elderly')
plt.xlabel('Range',fontsize = 15,color='blue')
plt.xticks(rotation=90)
plt.legend(loc='upper right',frameon=True)
plt.ylabel('sbp',fontsize = 15,color='blue')
plt.title('Age Range Values vs SBP',fontsize = 20,color='blue')
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
data.head()
# Out:
#    sbp  tobacco   ldl  adiposity  famhist  ...  Obesity  Alcohol  age  chd  AgeRange
# 0  160    12.00  5.73      23.11        1  ...    25.30    97.20   52    1         1
# 1  144     0.01  4.41      28.61        0  ...    28.87     2.06   63    1         2
# 2  118     0.08  3.48      32.28        1  ...    29.14     3.81   46    0         1
# 3  170     7.50  6.41      38.03        1  ...    31.99    24.26   58    1         2
# 4  134    13.60  3.50      27.78        1  ...    25.99    57.34   49    1         1
#
# [5 rows x 11 columns]

# %%
data_filter_mean=data[(data['chd']==1)&(data['age']>50)].groupby('famhist')[['sbp','ldl','tobacco']].mean()

# %%
data_filter_mean.unstack()
# Out:
#          famhist
# sbp      0          145.848485
#          1          148.523810
# ldl      0            5.443636
#          1            5.838254
# tobacco  0            8.648182
#          1            6.007143
# dtype: float64

# %%
for i,col in enumerate(data.columns.values):
    plt.subplot(5,3,i+1)
    plt.scatter([i for i in range(462)],data[col].values.tolist())
    plt.title(col)
    fig,ax=plt.gcf(),plt.gca()
    fig.set_size_inches(10,10)
    plt.tight_layout()
plt.show()

# %%
#Let's see how the correlation values between them
data.corr()
# Out:
#                 sbp   tobacco       ldl  ...       age       chd  AgeRange
# sbp        1.000000  0.212247  0.158296  ...  0.388771  0.192354  0.385820
# tobacco    0.212247  1.000000  0.158905  ...  0.450330  0.299718  0.399259
# ldl        0.158296  0.158905  1.000000  ...  0.311799  0.263053  0.240135
# adiposity  0.356500  0.286640  0.440432  ...  0.625954  0.254121  0.498659
# famhist    0.085645  0.088601  0.161353  ...  0.239667  0.272373  0.184344
# type a    -0.057454 -0.014608  0.044048  ... -0.102606  0.103156 -0.108090
# Obesity    0.238067  0.124529  0.330506  ...  0.291777  0.100095  0.181272
# Alcohol    0.140096  0.200813 -0.033403  ...  0.101125  0.062531  0.043542
# age        0.388771  0.450330  0.311799  ...  1.000000  0.372973  0.853206
# chd        0.192354  0.299718  0.263053  ...  0.372973  1.000000  0.285780
# AgeRange   0.385820  0.399259  0.240135  ...  0.853206  0.285780  1.000000
#
# [11 rows x 11 columns]
