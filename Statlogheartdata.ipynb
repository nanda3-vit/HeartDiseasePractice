# %% [markdown]
# <a href="https://colab.research.google.com/github/nanda3-vit/HeartDiseasePractice/blob/main/Statlogheartdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/sample_data/3.StatlogHDataset.csv')

# %%
print('Data First 5 Rows Show\n')
data.head()
# Out:
# Data First 5 Rows Show
#    age  sex  chest  ...  number_of_major_vessels  thal  class[present-1,absent-0]
# 0   70    1      4  ...                        3     3                          1
# 1   67    0      3  ...                        0     7                          0
# 2   57    1      2  ...                        0     7                          1
# 3   64    1      4  ...                        1     7                          0
# 4   74    0      2  ...                        1     3                          0
#
# [5 rows x 14 columns]

# %%
print('Data Last 5 Rows Show\n')
data.tail()
# Out:
# Data Last 5 Rows Show
#      age  sex  chest  ...  number_of_major_vessels  thal  class[present-1,absent-0]
# 265   52    1      3  ...                        0     7                          0
# 266   44    1      2  ...                        0     7                          0
# 267   56    0      2  ...                        0     3                          0
# 268   57    1      4  ...                        0     6                          0
# 269   67    1      4  ...                        3     3                          1
#
# [5 rows x 14 columns]

# %%
print('Data Show Describe\n')
data.describe()
# Out:
# Data Show Describe
#               age         sex  ...        thal  class[present-1,absent-0]
# count  270.000000  270.000000  ...  270.000000                 270.000000
# mean    54.433333    0.677778  ...    4.696296                   0.444444
# std      9.109067    0.468195  ...    1.940659                   0.497827
# min     29.000000    0.000000  ...    3.000000                   0.000000
# 25%     48.000000    0.000000  ...    3.000000                   0.000000
# 50%     55.000000    1.000000  ...    3.000000                   0.000000
# 75%     61.000000    1.000000  ...    7.000000                   1.000000
# max     77.000000    1.000000  ...    7.000000                   1.000000
#
# [8 rows x 14 columns]

# %%
print('Data Show Info\n')
data.info()
# Out:
# Data Show Info
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   270 non-null    int64
#  1   sex                                   270 non-null    int64
#  2   chest                                 270 non-null    int64
#  3   resting_blood_pressure                270 non-null    int64
#  4   serum_cholestoral                     270 non-null    int64
#  5   fasting_blood_sugar                   270 non-null    int64
#  6   resting_electrocardiographic_results  270 non-null    int64
#  7   maximum_heart_rate_achieved           270 non-null    int64
#  8   exercise_induced_angina               270 non-null    int64
#  9   oldpeak                               270 non-null    float64
#  10  slope                                 270 non-null    int64
#  11  number_of_major_vessels               270 non-null    int64
#  12  thal                                  270 non-null    int64
#  13  class[present-1,absent-0]             270 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 29.7 KB

# %%
print('Data Show Columns:\n')
data.columns
# Out:
# Data Show Columns:
# Index(['age', 'sex', 'chest', 'resting_blood_pressure', 'serum_cholestoral',
#        'fasting_blood_sugar', 'resting_electrocardiographic_results',
#        'maximum_heart_rate_achieved', 'exercise_induced_angina', 'oldpeak',
#        'slope', 'number_of_major_vessels', 'thal',
#        'class[present-1,absent-0]'],
#       dtype='object')

# %%
data.sample(frac=0.01)
# Out:
#      age  sex  chest  ...  number_of_major_vessels  thal  class[present-1,absent-0]
# 74    67    0      4  ...                        2     3                          0
# 253   51    1      3  ...                        0     3                          0
# 24    54    0      2  ...                        1     3                          0
#
# [3 rows x 14 columns]

# %%
data.sample(5)
# Out:
#      age  sex  chest  ...  number_of_major_vessels  thal  class[present-1,absent-0]
# 64    63    1      1  ...                        0     6                          0
# 69    47    1      3  ...                        0     3                          1
# 174   34    1      1  ...                        0     3                          0
# 49    65    0      4  ...                        3     7                          1
# 156   55    1      4  ...                        0     7                          1
#
# [5 rows x 14 columns]

# %%
print('Data Show Columns:\n')
data.columns
# Out:
# Data Show Columns:
# Index(['Age', 'Sex', 'Cp', 'Trestbps', 'Chol', 'Fbs', 'Restecg', 'Thalach',
#        'Exang', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'class[present-1,absent-0]'],
#       dtype='object')

# %%
data=data.rename(columns={'age':'Age','sex':'Sex','chest':'Cp','resting_blood_pressure':'Trestbps','serum_cholestoral':'Chol','fasting_blood_sugar':'Fbs',
                          'resting_electrocardiographic_results':'Restecg','maximum_heart_rate_achieved':'Thalach','exercise_induced_angina':'Exang',
                          'oldpeak':'Oldpeak','slope':'Slope','number_of_major_vessels':'Ca','thal':'Thal','class[present-1,absent-0]':'Target'})

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'Cp', 'Trestbps', 'Chol', 'Fbs', 'Restecg', 'Thalach',
#        'Exang', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'Target'],
#       dtype='object')

# %%
print('Data Shape Show\n')
data.shape
# Out:
# Data Shape Show
# (270, 14)

# %%
print('Data Sum of Null Values \n')
data.isnull().sum()
# Out:
# Data Sum of Null Values
# Age         0
# Sex         0
# Cp          0
# Trestbps    0
# Chol        0
# Fbs         0
# Restecg     0
# Thalach     0
# Exang       0
# Oldpeak     0
# Slope       0
# Ca          0
# Thal        0
# Target      0
# dtype: int64

# %%
data.isnull().values.any()
# Out:
# False

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True,fmt='.1f')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5},annot=True)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
data.Age.value_counts()[:10]
# Out:
# 54    16
# 58    15
# 51    12
# 57    12
# 59    12
# 60    12
# 62    11
# 52    11
# 44    10
# 41     9
# Name: Age, dtype: int64

# %%
sns.barplot(x=data.Age.value_counts()[:10].index,y=data.Age.value_counts()[:10].values)
plt.xlabel('Age')
plt.ylabel('Age Counter')
plt.title('Age Analysis System')
plt.show()

# %%
minAge=min(data.Age)
maxAge=max(data.Age)
meanAge=data.Age.mean()
print('Min Age :',minAge)
print('Max Age :',maxAge)
print('Mean Age :',meanAge)
# Out:
# Min Age : 29
# Max Age : 77
# Mean Age : 54.43333333333333

# %%
young_ages=data[(data.Age>=29)&(data.Age<40)]
middle_ages=data[(data.Age>=40)&(data.Age<55)]
elderly_ages=data[(data.Age>55)]
print('Young Ages :',len(young_ages))
print('Middle Ages :',len(middle_ages))
print('Elderly Ages :',len(elderly_ages))
# Out:
# Young Ages : 12
# Middle Ages : 120
# Elderly Ages : 132

# %%
sns.barplot(x=['young ages','middle ages','elderly ages'],y=[len(young_ages),len(middle_ages),len(elderly_ages)])
plt.xlabel('Age Range')
plt.ylabel('Age Counts')
plt.title('Ages State in Dataset')
plt.show()

# %%
data['AgeRange']=0
youngAge_index=data[(data.Age>=29)&(data.Age<40)].index
middleAge_index=data[(data.Age>=40)&(data.Age<55)].index
elderlyAge_index=data[(data.Age>55)].index

# %%
for index in elderlyAge_index:
    data.loc[index,'AgeRange']=2
    
for index in middleAge_index:
    data.loc[index,'AgeRange']=1

for index in youngAge_index:
    data.loc[index,'AgeRange']=0

# %%
sns.swarmplot(x="AgeRange", y="Age",hue='Sex',
              palette=["r", "c", "y"], data=data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 12.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_color_codes("deep")
sns.barplot(y="AgeRange", x="Sex", data=data,
            label="Total", color="g")
plt.show()

# %%
sns.countplot(elderly_ages.Sex)
plt.title("Elderly Sex Operations")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
elderly_ages.groupby(elderly_ages['Sex'])['Thalach'].agg('sum')
# Out:
# Sex
# 0     6877
# 1    11907
# Name: Thalach, dtype: int64

# %%
sns.barplot(x=elderly_ages.groupby(elderly_ages['Sex'])['Thalach'].agg('sum').index,y=elderly_ages.groupby(elderly_ages['Sex'])['Thalach'].agg('sum').values)
plt.title("Gender Group Thalach Show Sum Time")
plt.show()

# %%
sns.violinplot(data.Age, palette="Set3", bw=.2, cut=1, linewidth=1)
plt.xticks(rotation=90)
plt.title("Age Rates")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,7))
sns.violinplot(x=data.Age,y=data.Target)
plt.xticks(rotation=90)
plt.legend()
plt.title("Age & Target System")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
colors = ['red','blue','green']
explode = [0,0,0.1]
plt.figure(figsize = (5,5))
#plt.pie([target_0_agerang_0,target_1_agerang_0], explode=explode, labels=['Target 0 Age Range 0','Target 1 Age Range 0'], colors=colors, autopct='%1.1f%%')
plt.pie([len(young_ages),len(middle_ages),len(elderly_ages)],labels=['young ages','middle ages','elderly ages'],explode=explode,colors=colors, autopct='%1.1f%%')
plt.title('Age States',color = 'blue',fontsize = 15)
plt.show()

# %%
data.Sex.value_counts()
# Out:
# 1    183
# 0     87
# Name: Sex, dtype: int64

# %%
sns.countplot(data.Sex)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(data.Sex,hue=data.Slope)
plt.title('Slope & Sex Rates Show')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
total_genders_count=len(data.Sex)
male_count=len(data[data['Sex']==1])
female_count=len(data[data['Sex']==0])
print('Total Genders :',total_genders_count)
print('Male Count    :',male_count)
print('Female Count  :',female_count)
# Out:
# Total Genders : 270
# Male Count    : 183
# Female Count  : 87

# %%
print("Male State: {:.2f}%".format((male_count / (total_genders_count)*100)))
print("Female State: {:.2f}%".format((female_count / (total_genders_count)*100)))
# Out:
# Male State: 67.78%
# Female State: 32.22%

# %%
male_andtarget_on=len(data[(data.Sex==1)&(data['Target']==1)])
male_andtarget_off=len(data[(data.Sex==1)&(data['Target']==0)])
####
sns.barplot(x=['Male Target On','Male Target Off'],y=[male_andtarget_on,male_andtarget_off])
plt.xlabel('Male and Target State')
plt.ylabel('Count')
plt.title('State of the Gender')
plt.show()

# %%
male_andtarget_on=len(data[(data.Sex==1)&(data['Target']==1)])
male_andtarget_off=len(data[(data.Sex==1)&(data['Target']==0)])
####
sns.barplot(x=['Male Target On','Male Target Off'],y=[male_andtarget_on,male_andtarget_off])
plt.xlabel('Male and Target State')
plt.ylabel('Count')
plt.title('State of the Gender')
plt.show()

# %%
female_andtarget_on=len(data[(data.Sex==0)&(data['Target']==1)])
female_andtarget_off=len(data[(data.Sex==0)&(data['Target']==0)])
####
sns.barplot(x=['Female Target On','Female Target Off'],y=[female_andtarget_on,female_andtarget_off])
plt.xlabel('Female and Target State')
plt.ylabel('Count')
plt.title('State of the Gender')
plt.show()

# %%
sns.relplot(x="Trestbps", y="Age",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=data)

# %%
data.head()
# Out:
#    Age  Sex  Cp  Trestbps  Chol  ...  Slope  Ca  Thal  Target  AgeRange
# 0   70    1   4       130   322  ...      2   3     3       1         2
# 1   67    0   3       115   564  ...      2   0     7       0         2
# 2   57    1   2       124   261  ...      1   0     7       1         2
# 3   64    1   4       128   263  ...      2   1     7       0         2
# 4   74    0   2       120   269  ...      1   1     3       0         2
#
# [5 rows x 15 columns]

# %%
data.Cp.value_counts()
# Out:
# 4    129
# 3     79
# 2     42
# 1     20
# Name: Cp, dtype: int64

# %%
sns.countplot(data.Cp)
plt.xlabel('Chest Type')
plt.ylabel('Count')
plt.title('Chest Type vs Count State')
plt.show()
#0 status at least
#1 condition slightly distressed
#2 condition medium problem
#3 condition too bad
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
cp_zero_target_zero=len(data[(data.Cp==0)&(data.Target==0)])
cp_zero_target_one=len(data[(data.Cp==0)&(data.Target==1)])

# %%
sns.barplot(x=['cp_zero_target_zero','cp_zero_target_one'],y=[cp_zero_target_zero,cp_zero_target_one])
plt.show()

# %%
cp_one_target_zero=len(data[(data.Cp==1)&(data.Target==0)])
cp_one_target_one=len(data[(data.Cp==1)&(data.Target==1)])

# %%
sns.barplot(x=['cp_one_target_zero','cp_one_target_one'],y=[cp_one_target_zero,cp_one_target_one])
plt.show()

# %%
cp_two_target_zero=len(data[(data.Cp==2)&(data.Target==0)])
cp_two_target_one=len(data[(data.Cp==2)&(data.Target==1)])

# %%
sns.barplot(x=['cp_two_target_zero','cp_two_target_one'],y=[cp_two_target_zero,cp_two_target_one])
plt.show()

# %%
cp_three_target_zero=len(data[(data.Cp==3)&(data.Target==0)])
cp_three_target_one=len(data[(data.Cp==3)&(data.Target==1)])

# %%
sns.barplot(x=['cp_three_target_zero','cp_three_target_one'],y=[cp_three_target_zero,cp_three_target_one])
plt.show()

# %%
data.head(1)
# Out:
#    Age  Sex  Cp  Trestbps  Chol  ...  Slope  Ca  Thal  Target  AgeRange
# 0   70    1   4       130   322  ...      2   3     3       1         2
#
# [1 rows x 15 columns]

# %%
sns.lmplot(x="Trestbps", y="Chol",data=data,hue="Cp")
plt.show()

# %%
target_0_agerang_0=len(data[(data.Target==0)&(data.AgeRange==0)])
target_1_agerang_0=len(data[(data.Target==1)&(data.AgeRange==0)])

# %%
colors = ['red','cyan']
explode = [0,0.1]
plt.figure(figsize = (5,5))
plt.pie([target_0_agerang_0,target_1_agerang_0], explode=explode, labels=['Target 0 Age Range 0','Target 1 Age Range 0'], colors=colors, autopct='%1.1f%%')
plt.title('Target vs Age Range Young Age ',color = 'blue',fontsize = 15)
plt.show()

# %%
target_0_agerang_1=len(data[(data.Target==0)&(data.AgeRange==1)])
target_1_agerang_1=len(data[(data.Target==1)&(data.AgeRange==1)])

# %%
colors = ['yellow','blue']
explode = [0.1,0]
plt.figure(figsize = (5,5))
plt.pie([target_0_agerang_1,target_1_agerang_1], explode=explode, labels=['Target 0 Age Range 1','Target 1 Age Range 1'], colors=colors, autopct='%1.1f%%')
plt.title('Target vs Age Range Middle Age',color = 'blue',fontsize = 15)
plt.show()

# %%
target_0_agerang_2=len(data[(data.Target==0)&(data.AgeRange==2)])
target_1_agerang_2=len(data[(data.Target==1)&(data.AgeRange==2)])

# %%
colors = ['green','cyan']
explode = [0,0.1]
plt.figure(figsize = (5,5))
plt.pie([target_0_agerang_2,target_1_agerang_2], explode=explode, labels=['Target 0 Age Range 2','Target 1 Age Range 2'], colors=colors, autopct='%1.1f%%')
plt.title('Target vs Age Range Elderly Age ',color = 'blue',fontsize = 15)
plt.show()

# %%
data.Thalach.value_counts()[:20]
# Out:
# 162    10
# 160     9
# 163     8
# 125     7
# 172     7
# 152     6
# 132     6
# 142     6
# 150     6
# 173     6
# 158     6
# 156     5
# 161     5
# 168     5
# 170     5
# 157     5
# 154     5
# 178     5
# 147     5
# 143     5
# Name: Thalach, dtype: int64

# %%
sns.barplot(x=data.Thalach.value_counts()[:20].index,y=data.Thalach.value_counts()[:20].values)
plt.xlabel('Thalach')
plt.ylabel('Count')
plt.title('Thalach Counts')
plt.xticks(rotation=45)
plt.show()

# %%
sns.swarmplot(x=data.Age)
plt.title('Age Rates')
plt.show()

# %%
age_unique=sorted(data.Age.unique())
age_thalach_values=data.groupby('Age')['Thalach'].count().values
mean_thalach=[]
for i,age in enumerate(age_unique):
    mean_thalach.append(sum(data[data['Age']==age].Thalach)/age_thalach_values[i])

# %%
#data_sorted=data.sort_values(by='Age',ascending=True)
plt.figure(figsize=(10,5))
sns.pointplot(x=age_unique,y=mean_thalach,color='green',alpha=0.8)
plt.xlabel('Age',fontsize = 15,color='blue')
plt.xticks(rotation=45)
plt.ylabel('Thalach',fontsize = 15,color='blue')
plt.title('Age vs Thalach',fontsize = 15,color='blue')
plt.grid()
plt.show()

# %%
age_range_thalach=data.groupby('AgeRange')['Thalach'].mean()

# %%
sns.barplot(x=age_range_thalach.index,y=age_range_thalach.values)
plt.xlabel('Age Range Values')
plt.ylabel('Maximum Thalach By Age Range')
plt.title('illustration of the thalach to the age range')
plt.show()
#As shown in this graph, this rate decreases as the heart rate 
#is faster and in old age areas.

# %%
cp_thalach=data.groupby('Cp')['Thalach'].mean()

# %%
sns.barplot(x=cp_thalach.index,y=cp_thalach.values)
plt.xlabel('Degree of Chest Pain (Cp)')
plt.ylabel('Maximum Thalach By Cp Values')
plt.title('Illustration of thalach to degree of chest pain')
plt.show()
#As seen in this graph, it is seen that the heart rate is less 
#when the chest pain is low. But in cases where chest pain is 
#1, it is observed that the area is more. 2 and 3 were found to 
#be of the same degree.

# %%
data.Thal.value_counts()
# Out:
# 3    152
# 7    104
# 6     14
# Name: Thal, dtype: int64

# %%
sns.countplot(data.Thal)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data[(data.Thal==0)]
#as seen, only 50% was understood to be 50% target.
# Out:
# Empty DataFrame
# Columns: [Age, Sex, Cp, Trestbps, Chol, Fbs, Restecg, Thalach, Exang, Oldpeak, Slope, Ca, Thal, Target, AgeRange]
# Index: []

# %%
data[(data.Thal==3)]
#as seen, only 50% was understood to be 50% target.
# Out:
#      Age  Sex  Cp  Trestbps  Chol  ...  Slope  Ca  Thal  Target  AgeRange
# 0     70    1   4       130   322  ...      2   3     3       1         2
# 4     74    0   2       120   269  ...      1   1     3       0         2
# 12    44    1   3       140   235  ...      1   0     3       0         1
# 13    61    1   1       134   234  ...      2   2     3       1         2
# 14    57    0   4       128   303  ...      1   1     3       0         2
# ..   ...  ...  ..       ...   ...  ...    ...  ..   ...     ...       ...
# 260   58    0   3       120   340  ...      1   0     3       0         2
# 262   58    1   2       120   284  ...      2   0     3       1         2
# 263   49    1   2       130   266  ...      1   0     3       0         1
# 267   56    0   2       140   294  ...      2   0     3       0         2
# 269   67    1   4       160   286  ...      2   3     3       1         2
#
# [152 rows x 15 columns]

# %%
data[(data.Thal==6)]
#as seen, only 50% was understood to be 50% target.
# Out:
#      Age  Sex  Cp  Trestbps  Chol  ...  Slope  Ca  Thal  Target  AgeRange
# 6     56    1   3       130   256  ...      2   1     6       1         2
# 31    66    1   4       160   228  ...      1   0     6       0         2
# 44    59    1   3       126   218  ...      2   1     6       1         2
# 48    66    1   2       160   246  ...      2   3     6       1         2
# 50    42    1   4       136   315  ...      2   0     6       1         1
# 64    63    1   1       145   233  ...      3   0     6       0         2
# 65    57    1   4       150   276  ...      2   1     6       1         2
# 84    57    1   4       110   201  ...      2   0     6       0         2
# 140   64    1   4       145   212  ...      2   2     6       1         2
# 186   56    1   4       132   184  ...      2   1     6       1         2
# 225   41    1   2       135   203  ...      2   0     6       0         1
# 229   52    1   1       118   186  ...      2   0     6       0         1
# 246   65    1   4       110   248  ...      1   2     6       1         2
# 268   57    1   4       140   192  ...      2   0     6       0         2
#
# [14 rows x 15 columns]

# %%
data[(data.Thal==7)]
#as seen, only 50% was understood to be 50% target.
# Out:
#      Age  Sex  Cp  Trestbps  Chol  ...  Slope  Ca  Thal  Target  AgeRange
# 1     67    0   3       115   564  ...      2   0     7       0         2
# 2     57    1   2       124   261  ...      1   0     7       1         2
# 3     64    1   4       128   263  ...      2   1     7       0         2
# 5     65    1   4       120   177  ...      1   0     7       0         2
# 7     59    1   4       110   239  ...      2   1     7       1         2
# ..   ...  ...  ..       ...   ...  ...    ...  ..   ...     ...       ...
# 257   55    1   4       132   353  ...      2   1     7       1         0
# 261   60    1   4       130   206  ...      2   2     7       1         2
# 264   48    1   2       110   229  ...      3   0     7       1         1
# 265   52    1   3       172   199  ...      1   0     7       0         1
# 266   44    1   2       120   263  ...      1   0     7       0         1
#
# [104 rows x 15 columns]

# %%
data[(data['Thal']==3)].Target.value_counts()
sns.barplot(x=data[(data['Thal']==3)].Target.value_counts().index,y=data[(data['Thal']==3)].Target.value_counts().values)
plt.xlabel('Thal Value')
plt.ylabel('Count')
plt.title('Counter for Thal')
plt.show()

# %%
#Target 1
a=len(data[(data['Target']==1)&(data['Thal']==0)])
b=len(data[(data['Target']==1)&(data['Thal']==1)])
c=len(data[(data['Target']==1)&(data['Thal']==2)])
d=len(data[(data['Target']==1)&(data['Thal']==3)])
e=len(data[(data['Target']==1)&(data['Thal']==4)])
f=len(data[(data['Target']==1)&(data['Thal']==5)])
g=len(data[(data['Target']==1)&(data['Thal']==6)])
h=len(data[(data['Target']==1)&(data['Thal']==7)])
print('Target 1 Thal 0: ',a)
print('Target 1 Thal 1: ',b)
print('Target 1 Thal 2: ',c)
print('Target 1 Thal 3: ',d)
print('Target 1 Thal 4: ',e)
print('Target 1 Thal 5: ',f)
print('Target 1 Thal 6: ',g)
print('Target 1 Thal 7: ',h)

#so,Apparently, there is a rate at Thal 2.Now, draw graph
print('*'*50)
#Target 0
i=len(data[(data['Target']==0)&(data['Thal']==0)])
j=len(data[(data['Target']==0)&(data['Thal']==1)])
k=len(data[(data['Target']==0)&(data['Thal']==2)])
l=len(data[(data['Target']==0)&(data['Thal']==3)])
m=len(data[(data['Target']==0)&(data['Thal']==4)])
n=len(data[(data['Target']==0)&(data['Thal']==5)])
o=len(data[(data['Target']==0)&(data['Thal']==6)])
p=len(data[(data['Target']==0)&(data['Thal']==7)])
print('Target 0 Thal 0: ',i)
print('Target 0 Thal 1: ',j)
print('Target 0 Thal 2: ',k)
print('Target 0 Thal 3: ',l)
print('Target 0 Thal 4: ',m)
print('Target 0 Thal 5: ',n)
print('Target 0 Thal 6: ',o)
print('Target 0 Thal 7: ',p)
# Out:
# Target 1 Thal 0:  0
# Target 1 Thal 1:  0
# Target 1 Thal 2:  0
# Target 1 Thal 3:  33
# Target 1 Thal 4:  0
# Target 1 Thal 5:  0
# Target 1 Thal 6:  8
# Target 1 Thal 7:  79
# **************************************************
# Target 0 Thal 0:  0
# Target 0 Thal 1:  0
# Target 0 Thal 2:  0
# Target 0 Thal 3:  119
# Target 0 Thal 4:  0
# Target 0 Thal 5:  0
# Target 0 Thal 6:  6
# Target 0 Thal 7:  25

# %%
f,ax=plt.subplots(figsize=(7,7))
sns.barplot(y=['T 1&0 Th 0','T 1&0 Th 1','T 1&0 Th 2','Ta 1&0 Th 3','T 1&0 Th 4','T 1&0 Th 5','T 1&0 Th 6','Ta 1&0 Th 7'],x=[0,0,0,33,0,0,8,79],color='green',alpha=0.5,label='Target 1 Thal State')
sns.barplot(y=['T 1&0 Th 0','T 1&0 Th 1','T 1&0 Th 2','Ta 1&0 Th 3','T 1&0 Th 4','T 1&0 Th 5','T 1&0 Th 6','Ta 1&0 Th 7'],x=[0,0,0,119,0,0,6,25],color='red',alpha=0.7,label='Target 0 Thal State')
ax.legend(loc='lower right',frameon=True)
ax.set(xlabel='Target State and Thal Counter',ylabel='Target State and Thal State',title='Target VS Thal')
plt.xticks(rotation=90)
plt.show()
#so, there has been a very nice graphic display. This is the situation that best describes the situation.

# %%
data.Target.unique()
#only two values are shown.
#A value of 1 is the value of patient 0.
# Out:
# array([1, 0])

# %%
sns.countplot(data.Target)
plt.xlabel('Target')
plt.ylabel('Count')
plt.title('Target Counter 1 & 0')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(data.Target,hue=data.Sex)
plt.xlabel('Target')
plt.ylabel('Count')
plt.title('Target & Sex Counter 1 & 0')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#determine the age ranges of patients with and without sickness and make analyzes about them
age_counter_target_1=[]
age_counter_target_0=[]
for age in data.Age.unique():
    age_counter_target_1.append(len(data[(data['Age']==age)&(data.Target==1)]))
    age_counter_target_0.append(len(data[(data['Age']==age)&(data.Target==0)]))

#now, draw show on graph

# %%
#Target 1 & 0 show graph on scatter
plt.scatter(x=data.Age.unique(),y=age_counter_target_1,color='blue',label='Target 1')
plt.scatter(x=data.Age.unique(),y=age_counter_target_0,color='red',label='Target 0')
plt.legend(loc='upper right',frameon=True)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Target 0 & Target 1 State')
plt.show()

# %%
sns.lineplot(x="Sex", y="Oldpeak",
             hue="Target",data=data)
plt.show()

# %%
data.head()
# Out:
#    Age  Sex  Cp  Trestbps  Chol  ...  Slope  Ca  Thal  Target  AgeRange
# 0   70    1   4       130   322  ...      2   3     3       1         2
# 1   67    0   3       115   564  ...      2   0     7       0         2
# 2   57    1   2       124   261  ...      1   0     7       1         2
# 3   64    1   4       128   263  ...      2   1     7       0         2
# 4   74    0   2       120   269  ...      1   1     3       0         2
#
# [5 rows x 15 columns]

# %%
g = sns.catplot(x="AgeRange", y="Chol",
                 hue="Sex",
                 data=data, kind="bar")
plt.show()

# %%
ax = sns.barplot("Sex", "Chol", data=data,
                  linewidth=2.5, facecolor=(1, 1, 1, 0),
                  errcolor=".2", edgecolor=".2")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
male_young_t_1=data[(data['Sex']==1)&(data['AgeRange']==0)&(data['Target']==1)]
male_middle_t_1=data[(data['Sex']==1)&(data['AgeRange']==1)&(data['Target']==1)]
male_elderly_t_1=data[(data['Sex']==1)&(data['AgeRange']==2)&(data['Target']==1)]
print(len(male_young_t_1))
print(len(male_middle_t_1))
print(len(male_elderly_t_1))
# Out:
# 7
# 34
# 59

# %%
f,ax1=plt.subplots(figsize=(20,10))
sns.pointplot(x=np.arange(len(male_young_t_1)),y=male_young_t_1.Trestbps,color='lime',alpha=0.8,label='Young')
sns.pointplot(x=np.arange(len(male_middle_t_1)),y=male_middle_t_1.Trestbps,color='black',alpha=0.8,label='Middle')
sns.pointplot(x=np.arange(len(male_elderly_t_1)),y=male_elderly_t_1.Trestbps,color='red',alpha=0.8,label='Elderly')
plt.xlabel('Range',fontsize = 15,color='blue')
plt.xticks(rotation=90)
plt.legend(loc='upper right',frameon=True)
plt.ylabel('Trestbps',fontsize = 15,color='blue')
plt.title('Age Range Values vs Trestbps',fontsize = 20,color='blue')
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
data.head()
# Out:
#    Age  Sex  Cp  Trestbps  Chol  ...  Slope  Ca  Thal  Target  AgeRange
# 0   70    1   4       130   322  ...      2   3     3       1         2
# 1   67    0   3       115   564  ...      2   0     7       0         2
# 2   57    1   2       124   261  ...      1   0     7       1         2
# 3   64    1   4       128   263  ...      2   1     7       0         2
# 4   74    0   2       120   269  ...      1   1     3       0         2
#
# [5 rows x 15 columns]

# %%
data_filter_mean=data[(data['Target']==1)&(data['Age']>50)].groupby('Sex')[['Trestbps','Chol','Thalach']].mean()

# %%
data_filter_mean.unstack()
# Out:
#           Sex
# Trestbps  0      149.526316
#           1      133.600000
# Chol      0      287.315789
#           1      254.866667
# Thalach   0      143.894737
#           1      135.506667
# dtype: float64

# %%
for i,col in enumerate(data.columns.values):
    plt.subplot(5,3,i+1)
    plt.scatter([i for i in range(270)],data[col].values.tolist())
    plt.title(col)
    fig,ax=plt.gcf(),plt.gca()
    fig.set_size_inches(10,10)
    plt.tight_layout()
plt.show()

# %%
#Let's see how the correlation values between them
data.corr()
# Out:
#                Age       Sex        Cp  ...      Thal    Target  AgeRange
# Age       1.000000 -0.094401  0.096920  ...  0.106100  0.212322  0.814788
# Sex      -0.094401  1.000000  0.034636  ...  0.391046  0.297721 -0.055052
# Cp        0.096920  0.034636  1.000000  ...  0.262659  0.417436  0.090006
# Trestbps  0.273053 -0.062693 -0.043196  ...  0.132045  0.155383  0.217379
# Chol      0.220056 -0.201647  0.090465  ...  0.028836  0.118021  0.155897
# Fbs       0.123458  0.042140 -0.098537  ...  0.049237 -0.016319  0.137674
# Restecg   0.128171  0.039253  0.074325  ...  0.007337  0.182091  0.142061
# Thalach  -0.402215 -0.076101 -0.317682  ... -0.253397 -0.418514 -0.306738
# Exang     0.098297  0.180022  0.353160  ...  0.321449  0.419303  0.069552
# Oldpeak   0.194234  0.097412  0.167244  ...  0.324333  0.417967  0.141898
# Slope     0.159774  0.050545  0.136900  ...  0.283678  0.337616  0.120830
# Ca        0.356081  0.086830  0.225890  ...  0.255648  0.455336  0.304500
# Thal      0.106100  0.391046  0.262659  ...  1.000000  0.525020  0.135790
# Target    0.212322  0.297721  0.417436  ...  0.525020  1.000000  0.210335
# AgeRange  0.814788 -0.055052  0.090006  ...  0.135790  0.210335  1.000000
#
# [15 rows x 15 columns]
